# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
n=np.random.randint(2,10,40)
n
# Out:
# array([3, 9, 9, 2, 4, 2, 4, 5, 2, 2, 4, 6, 5, 5, 8, 5, 8, 6, 8, 3, 4, 9,
#        2, 8, 8, 7, 5, 3, 6, 2, 7, 2, 8, 5, 3, 3, 6, 7, 6, 6])

# %%
#convert list n to data frame
df=pd.DataFrame(n)

#count each variable how many times repeated 
df=pd.DataFrame(df[0].value_counts())
df
# Out:
#    0
# 2  7
# 8  6
# 6  6
# 5  6
# 3  5
# 4  4
# 9  3
# 7  3

# %%
length=len(n)
length
# Out:
# 40

# %%
#give name for the column
df.columns=['Counts']
df
# Out:
#    Counts
# 2       7
# 8       6
# 6       6
# 5       6
# 3       5
# 4       4
# 9       3
# 7       3

# %%
# To find probasbility mass function(PMF) take count value of each number and devide by entire length
df['Prob']=df['Counts']/length
df
# Out:
#    Counts   Prob
# 2       7  0.175
# 8       6  0.150
# 6       6  0.150
# 5       6  0.150
# 3       5  0.125
# 4       4  0.100
# 9       3  0.075
# 7       3  0.075

# %%
#Plot PMF
plt.bar(df['Counts'],df['Prob'])
# Out:
# <BarContainer object of 8 artists>

# %%
# Plot pmf using seaborne
import seaborn as sns
sns.barplot(df['Counts'],df['Prob'])

# %%
# Another example of pmf
data={'Candy':['Blue','Orange','Green','Purple'],
     'Total':[30000,10000,20000,12000]}
df=pd.DataFrame(data)
df
# Out:
#     Candy  Total
# 0    Blue  30000
# 1  Orange  10000
# 2   Green  20000
# 3  Purple  12000

# %%
df["pmf"]=df["Total"]/df["Total"].sum()
df
# Out:
#     Candy  Total       pmf
# 0    Blue  30000  0.416667
# 1  Orange  10000  0.138889
# 2   Green  20000  0.277778
# 3  Purple  12000  0.166667

# %%
# plot it
sns.barplot(df['Candy'],df['pmf'])

# %%
data=np.random.normal(size=100)
data=np.append(data,[1.2,1.2,1.2,1.2,1.2])
sns.distplot(data)

# %%
import scipy.stats as stata
mu=20
sigma=2
h=sorted(np.random.normal(mu,sigma,100))

# %%
import scipy.stats as stats
plt.figure(figsize=(10,5))
fit=stats.norm.pdf(h,np.mean(h),np.std(h))
plt.plot(h,fit,'-o')
plt.hist(h,density=True)
# Out:
# (array([0.04606679, 0.05758349, 0.10365028, 0.17275047, 0.16123377,
#         0.17275047, 0.18426716, 0.13820037, 0.06910019, 0.04606679]),
#  array([15.41377836, 16.28208282, 17.15038728, 18.01869174, 18.88699621,
#         19.75530067, 20.62360513, 21.49190959, 22.36021405, 23.22851851,
#         24.09682298]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Cumulative distribution function

# %%
import scipy.stats as ss
x=np.linspace(-5,5,5000)
mu=0
sigma=1
y_pdf=ss.norm.pdf(x,mu,sigma)
y_cdf=ss.norm.cdf(x,mu,sigma)
plt.plot(x,y_pdf, label='pdf')
plt.plot(x,y_cdf, label='cdf')

# %%
import scipy.stats as stats
plt.figure(figsize=(10,5))
fit=stats.norm.cdf(h,np.mean(h),np.std(h))
plt.plot(h,fit,'-o')
plt.hist(h,density=True)
# Out:
# (array([0.04606679, 0.05758349, 0.10365028, 0.17275047, 0.16123377,
#         0.17275047, 0.18426716, 0.13820037, 0.06910019, 0.04606679]),
#  array([15.41377836, 16.28208282, 17.15038728, 18.01869174, 18.88699621,
#         19.75530067, 20.62360513, 21.49190959, 22.36021405, 23.22851851,
#         24.09682298]),
#  <a list of 10 Patch objects>)
